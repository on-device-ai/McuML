# %%
import os

root_path = ''
proj_path = ''
class cd:
    """Context manager for changing the current working directory"""
    def __init__(self, newPath):
        self.newPath = os.path.expanduser(newPath)

    def __enter__(self):
        self.savedPath = os.getcwd()
        os.chdir(self.newPath)

    def __exit__(self, etype, value, traceback):
        os.chdir(self.savedPath)
        
with cd('..\\..\\'):
    root_path = os.getcwd()
proj_path = os.getcwd()

# %%
cmd = proj_path + '\\mbed_cmd.bat mbed --version'
print(os.popen(cmd).read())
# Out:
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Ran pip subprocess with arguments:
# ['C:\\Projects\\McuML\\miniconda3\\envs\\mbed\\python.exe', '-m', 'pip', 'install', '-U', '-r', 'C:\\Projects\\McuML\\projects\\tflite_micro_classify_heartbeats\\condaenv.1h0571g5.requirements.txt']
# Pip subprocess output:
# Collecting appdirs==1.4.4
#
#   Using cached https://files.pythonhosted.org/packages/3b/00/2344469e2084fb287c2e0b57b72910309874c3245463acd6cf5e3db69324/appdirs-1.4.4-py2.py3-none-any.whl
#
# Collecting backports-functools-lru-cache==1.6.1
#
#   Using cached https://files.pythonhosted.org/packages/da/d1/080d2bb13773803648281a49e3918f65b31b7beebf009887a529357fd44a/backports.functools_lru_cache-1.6.1-py2.py3-none-any.whl
#
# Collecting beautifulsoup4==4.9.1
#
#   Using cached https://files.pythonhosted.org/packages/c2/39/1efce3dc73e657c43f436533d49be1491bf8fc830caa70188d73bfd03b8d/beautifulsoup4-4.9.1-py2-none-any.whl
#
# Collecting chardet==3.0.4
#
#   Using cached https://files.pythonhosted.org/packages/bc/a9/01ffebfb562e4274b6487b4bb1ddec7ca55ec7510b22e4c51f14098443b8/chardet-3.0.4-py2.py3-none-any.whl
#
# Collecting colorama==0.4.3
#
#   Using cached https://files.pythonhosted.org/packages/c9/dc/45cdef1b4d119eb96316b3117e6d5708a08029992b2fee2c143c7a0a5cc5/colorama-0.4.3-py2.py3-none-any.whl
#
# Collecting fasteners==0.15
#
#   Using cached https://files.pythonhosted.org/packages/18/bd/55eb2d6397b9c0e263af9d091ebdb756b15756029b3cededf6461481bc63/fasteners-0.15-py2.py3-none-any.whl
#
# Processing c:\users\4441s\appdata\local\pip\cache\wheels\8b\99\a0\81daf51dcd359a9377b110a8a886b3895921802d2fc1b2397e\future-0.18.2-cp27-none-any.whl
#
# Collecting idna==2.10
#
#   Using cached https://files.pythonhosted.org/packages/a2/38/928ddce2273eaa564f6f50de919327bf3a00f091b5baba8dfa9460f3a8a8/idna-2.10-py2.py3-none-any.whl
#
# Collecting intelhex==2.2.1
#
#   Using cached https://files.pythonhosted.org/packages/bf/77/bf670318b3db325c71e2ac6a90b7bcfdf9fc739b7cf6aebb31715721623e/intelhex-2.2.1-py2.py3-none-any.whl
#
# Collecting junit-xml==1.9
#
#   Using cached https://files.pythonhosted.org/packages/2a/93/2d896b5fd3d79b4cadd8882c06650e66d003f465c9d12c488d92853dff78/junit_xml-1.9-py2.py3-none-any.whl
#
# Collecting lockfile==0.12.2
#
#   Using cached https://files.pythonhosted.org/packages/c8/22/9460e311f340cb62d26a38c419b1381b8593b0bb6b5d1f056938b086d362/lockfile-0.12.2-py2.py3-none-any.whl
#
# Collecting mbed-cli==1.10.4
#
#   Using cached https://files.pythonhosted.org/packages/0a/a4/a749f8a0853bb16662b5712bbfeb564d4e023192fa785cafda2a7b5467d8/mbed_cli-1.10.4-py2.py3-none-any.whl
#
# Processing c:\users\4441s\appdata\local\pip\cache\wheels\24\fd\56\a4b6e4972c9f3364d2353398c31a00f6291d7d95542ef734fd\mbed_os_tools-0.0.15-cp27-none-any.whl
#
# Collecting monotonic==1.5
#
#   Using cached https://files.pythonhosted.org/packages/ac/aa/063eca6a416f397bd99552c534c6d11d57f58f2e94c14780f3bbf818c4cf/monotonic-1.5-py2.py3-none-any.whl
#
# Processing c:\users\4441s\appdata\local\pip\cache\wheels\80\34\1c\3967380d9676d162cb59513bd9dc862d0584e045a162095606\prettytable-0.7.2-cp27-none-any.whl
#
# Collecting pyserial==3.4
#
#   Using cached https://files.pythonhosted.org/packages/0d/e4/2a744dd9e3be04a0c0907414e2a01a7c88bb3915cbe3c8cc06e209f59c30/pyserial-3.4-py2.py3-none-any.whl
#
# Collecting requests==2.24.0
#
#   Using cached https://files.pythonhosted.org/packages/45/1e/0c169c6a5381e241ba7404532c16a21d86ab872c9bed8bdcd4c423954103/requests-2.24.0-py2.py3-none-any.whl
#
# Collecting six==1.15.0
#
#   Using cached https://files.pythonhosted.org/packages/ee/ff/48bde5c0f013094d729fe4b0316ba2a24774b3ff1c52d924a8a4cb04078a/six-1.15.0-py2.py3-none-any.whl
#
# Collecting soupsieve==1.9.6
#
#   Using cached https://files.pythonhosted.org/packages/39/36/f35056eb9978a622bbcedc554993d10777e3c6ff1ca24cde53f4be9c5fc4/soupsieve-1.9.6-py2.py3-none-any.whl
#
# Collecting urllib3==1.25.10
#
#   Using cached https://files.pythonhosted.org/packages/9f/f0/a391d1463ebb1b233795cabfc0ef38d3db4442339de68f847026199e69d7/urllib3-1.25.10-py2.py3-none-any.whl
#
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in c:\projects\mcuml\miniconda3\envs\mbed\lib\site-packages (from requests==2.24.0->-r C:\Projects\McuML\projects\tflite_micro_classify_heartbeats\condaenv.1h0571g5.requirements.txt (line 17)) (2019.11.28)
#
# Installing collected packages: appdirs, backports-functools-lru-cache, soupsieve, beautifulsoup4, chardet, colorama, monotonic, six, fasteners, future, idna, intelhex, junit-xml, lockfile, pyserial, urllib3, requests, prettytable, mbed-os-tools, mbed-cli
#
# Successfully installed appdirs-1.4.4 backports-functools-lru-cache beautifulsoup4-4.9.1 chardet-3.0.4 colorama-0.4.3 fasteners-0.15 future-0.18.2 idna-2.10 intelhex-2.2.1 junit-xml-1.9 lockfile-0.12.2 mbed-cli-1.10.4 mbed-os-tools-0.0.15 monotonic-1.5 prettytable-0.7.2 pyserial-3.4 requests-2.24.0 six-1.15.0 soupsieve-1.9.6 urllib3-1.25.10
#
#
# #
# # To activate this environment, use
# #
# #     $ conda activate mbed
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
#
# (mbed) C:\Projects\McuML\projects\tflite_micro_classify_heartbeats>mbed --version
# 1.10.4

# %%
gcc_path = root_path + '\\tensorflow\\tensorflow\\lite\\micro\\tools\\make\\downloads\\\gcc_embedded\\bin'

cmd = proj_path + '\\mbed_cmd.bat mbed config -G GCC_ARM_PATH ' + gcc_path
print(os.popen(cmd).read())
# Out:
# (mbed) C:\Projects\McuML\projects\tflite_micro_classify_heartbeats>mbed config -G GCC_ARM_PATH C:\Projects\McuML\tensorflow\tensorflow\lite\micro\tools\make\downloads\\gcc_embedded\bin
# [mbed] C:\Projects\McuML\tensorflow\tensorflow\lite\micro\tools\make\downloads\\gcc_embedded\bin now set as global GCC_ARM_PATH

# %%
cmd = proj_path + '\\mbed_cmd.bat mbed config --list'
print(os.popen(cmd).read())
# Out:
# (mbed) C:\Projects\McuML\projects\tflite_micro_classify_heartbeats>mbed config --list
# [mbed] Global config:
# GCC_ARM_PATH=C:\Projects\McuML\tensorflow\tensorflow\lite\micro\tools\make\downloads\\gcc_embedded\bin
#
# [mbed] Local config (C:\Projects\McuML\projects\tflite_micro_classify_heartbeats):
# Couldn't find valid mbed program in C:\Projects\McuML\projects\tflite_micro_classify_heartbeats

# %% [markdown]
# # Deploy to STM32F746

# %%
os.chdir(proj_path + '\\mbed')

# %%
cmd = proj_path + '\\mbed_cmd.bat mbed config root .'
print(os.popen(cmd).read())
# Out:
# (mbed) C:\Projects\McuML\projects\tflite_micro_classify_heartbeats\mbed>mbed config root .
# [mbed] . now set as default root in program "mbed"

# %%
cmd = proj_path + '\\mbed_cmd.bat mbed deploy'
print(os.popen(cmd).read())
# Out:
# (mbed) C:\Projects\McuML\projects\tflite_micro_classify_heartbeats\mbed>mbed deploy
# [mbed] Working path "C:\Projects\McuML\projects\tflite_micro_classify_heartbeats\mbed" (program)
# [mbed] Adding library "BSP_DISCO_F746NG" from "https://os.mbed.com/teams/ST/code/BSP_DISCO_F746NG" at rev #df2ea349c37a
# [mbed] Adding library "LCD_DISCO_F746NG" from "https://os.mbed.com/teams/ST/code/LCD_DISCO_F746NG" at rev #d44525b1de98
# [mbed] Adding library "mbed-os" from "https://github.com/ARMmbed/mbed-os" at rev #8ef742a49c16
# [mbed] Auto-installing missing Python modules (pyyaml, jsonschema, mbed_cloud_sdk, jinja2, mbed_ls, mbed_host_tests, mbed_greentea, pyelftools, manifest_tool, icetea, pycryptodome, pyusb, hidapi, cmsis_pack_manager, pywin32, wmi, psutil)...

# %%
import fileinput, glob;
for filename in glob.glob("mbed-os/tools/profiles/*.json"):
    for line in fileinput.input(filename, inplace=True):
        print(line.replace("\"-std=gnu++98\"","\"-std=c++11\", \"-fpermissive\""))

# %%
cmd = proj_path + '\\mbed_cmd.bat mbed compile -m DISCO_F746NG -t GCC_ARM'
print(os.popen(cmd).read())
# Out:
# (mbed) C:\Projects\McuML\projects\tflite_micro_classify_heartbeats\mbed>mbed compile -m DISCO_F746NG -t GCC_ARM
# [Warning] @,: Compiler version mismatch: Have 7.3.1; expected version >= 6.0.0 and < 7.0.0
# Building project mbed (DISCO_F746NG, GCC_ARM)
# Scan: mbed
# Compile [  0.3%]: ft5336.c
# Compile [  0.7%]: ov9655.c
# Compile [  1.0%]: wm8994.c
# Compile [  1.3%]: stm32746g_discovery.c
# Compile [  1.7%]: stm32746g_discovery_camera.c
# Compile [  2.0%]: stm32746g_discovery_eeprom.c
# Compile [  2.3%]: stm32746g_discovery_audio.c
# Compile [  2.7%]: stm32746g_discovery_qspi.c
# Compile [  3.0%]: stm32746g_discovery_sd.c
# Compile [  3.3%]: stm32746g_discovery_sdram.c
# Compile [  3.7%]: stm32746g_discovery_lcd.c
# Compile [  4.0%]: font12.c
# Compile [  4.3%]: font16.c
# Compile [  4.7%]: font20.c
# Compile [  5.0%]: font8.c
# Compile [  5.3%]: font24.c
# Compile [  5.7%]: stm32746g_discovery_ts.c
# Compile [  6.0%]: mbed_tz_context.c
# Compile [  6.3%]: AnalogOut.cpp
# Compile [  6.7%]: BusIn.cpp
# Compile [  7.0%]: AnalogIn.cpp
# Compile [  7.3%]: BusInOut.cpp
# Compile [  7.7%]: BusOut.cpp
# Compile [  8.0%]: LCD_DISCO_F746NG.cpp
# Compile [  8.3%]: DigitalIn.cpp
# Compile [  8.7%]: DigitalInOut.cpp
# Compile [  9.0%]: CAN.cpp
# Compile [  9.3%]: DigitalOut.cpp
# Compile [  9.7%]: Ethernet.cpp
# Compile [ 10.0%]: I2CSlave.cpp
# Compile [ 10.3%]: InterruptIn.cpp
# Compile [ 10.7%]: FlashIAP.cpp
# Compile [ 11.0%]: InterruptManager.cpp
# [Warning] CallChain.h@77,37: 'CallChain' is deprecated: CallChain has been deprecated and will be removed. [-Wdeprecated-declarations]
# [Warning] InterruptManager.h@204,40: 'CallChain' is deprecated: CallChain has been deprecated and will be removed. [-Wdeprecated-declarations]
# [Warning] InterruptManager.cpp@63,60: 'CallChain' is deprecated: CallChain has been deprecated and will be removed. [-Wdeprecated-declarations]
# [Warning] InterruptManager.cpp@92,32: 'CallChain' is deprecated: CallChain has been deprecated and will be removed. [-Wdeprecated-declarations]
# Compile [ 11.3%]: I2C.cpp
# Compile [ 11.7%]: PortIn.cpp
# Compile [ 12.0%]: PortOut.cpp
# Compile [ 12.3%]: PortInOut.cpp
# Compile [ 12.7%]: MbedCRC.cpp
# Compile [ 13.0%]: PwmOut.cpp
# Compile [ 13.3%]: ResetReason.cpp
# Compile [ 13.7%]: RawSerial.cpp
# Compile [ 14.0%]: SPISlave.cpp
# Compile [ 14.3%]: QSPI.cpp
# [Warning] QSPI.cpp@49,10: unused variable 'success' [-Wunused-variable]
# Compile [ 14.7%]: SerialWireOutput.cpp
# Compile [ 15.0%]: SPI.cpp
# Compile [ 15.3%]: Serial.cpp
# Compile [ 15.7%]: TableCRC.cpp
# Compile [ 16.0%]: Timeout.cpp
# Compile [ 16.3%]: SerialBase.cpp
# Compile [ 16.7%]: Ticker.cpp
# Compile [ 17.0%]: Timer.cpp
# Compile [ 17.3%]: Watchdog.cpp
# Compile [ 17.7%]: TimerEvent.cpp
# Compile [ 18.0%]: UARTSerial.cpp
# Compile [ 18.3%]: BufferedBlockDevice.cpp
# Compile [ 18.7%]: ChainingBlockDevice.cpp
# Compile [ 19.0%]: ExhaustibleBlockDevice.cpp
# Compile [ 19.3%]: ObservingBlockDevice.cpp
# Compile [ 19.7%]: FlashSimBlockDevice.cpp
# Compile [ 20.0%]: ProfilingBlockDevice.cpp
# Compile [ 20.3%]: HeapBlockDevice.cpp
# Compile [ 20.7%]: SlicingBlockDevice.cpp
# Compile [ 21.0%]: ReadOnlyBlockDevice.cpp
# Compile [ 21.3%]: MBRBlockDevice.cpp
# Compile [ 21.7%]: mbed_critical_section_api.c
# Compile [ 22.0%]: mbed_flash_api.c
# Compile [ 22.3%]: mbed_itm_api.c
# Compile [ 22.7%]: LowPowerTickerWrapper.cpp
# Compile [ 23.0%]: mbed_gpio.c
# Compile [ 23.3%]: mbed_gpio_irq.c
# Compile [ 23.7%]: mbed_lp_ticker_api.c
# Compile [ 24.0%]: mbed_lp_ticker_wrapper.cpp
# Compile [ 24.3%]: mbed_pinmap_common.c
# Compile [ 24.7%]: mbed_pinmap_default.c
# Compile [ 25.0%]: mbed_ticker_api.c
# Compile [ 25.3%]: mbed_us_ticker_api.c
# Compile [ 25.7%]: mbed_mpu_v7m.c
# Compile [ 26.0%]: mbed_mpu_v8m.c
# Compile [ 26.3%]: mbed_usb_phy.cpp
# Compile [ 26.7%]: mbed_os_timer.cpp
# Compile [ 27.0%]: SysTimer.cpp
# Compile [ 27.3%]: mbed_thread.cpp
# Compile [ 27.7%]: mstd_mutex.cpp
# Compile [ 28.0%]: CriticalSectionLock.cpp
# Compile [ 28.3%]: CallChain.cpp
# [Warning] CallChain.h@77,37: 'CallChain' is deprecated: CallChain has been deprecated and will be removed. [-Wdeprecated-declarations]
# Compile [ 28.7%]: CThunkBase.cpp
# Compile [ 29.0%]: ATCmdParser.cpp
# Compile [ 29.3%]: FileHandle.cpp
# Compile [ 29.7%]: DeepSleepLock.cpp
# Compile [ 30.0%]: FileBase.cpp
# Compile [ 30.3%]: FilePath.cpp
# Compile [ 30.7%]: FileSystemHandle.cpp
# Compile [ 31.0%]: except.S
# Compile [ 31.3%]: LocalFileSystem.cpp
# Compile [ 31.7%]: mbed_fault_handler.c
# Compile [ 32.0%]: mbed_application.c
# Compile [ 32.3%]: mbed_assert.c
# Compile [ 32.7%]: mbed_atomic_impl.c
# Compile [ 33.0%]: Stream.cpp
# Compile [ 33.3%]: mbed_alloc_wrappers.cpp
# Compile [ 33.7%]: mbed_board.c
# Compile [ 34.0%]: mbed_critical.c
# Compile [ 34.3%]: mbed_error_hist.c
# Compile [ 34.7%]: mbed_error.c
# Compile [ 35.0%]: mbed_interface.c
# Compile [ 35.3%]: mbed_mktime.c
# Compile [ 35.7%]: mbed_mpu_mgmt.c
# Compile [ 36.0%]: mbed_power_mgmt.c
# Compile [ 36.3%]: mbed_poll.cpp
# Compile [ 36.7%]: mbed_mem_trace.cpp
# Compile [ 37.0%]: mbed_sdk_boot.c
# Compile [ 37.3%]: mbed_semihost_api.c
# Compile [ 37.7%]: mbed_stats.c
# Compile [ 38.0%]: mbed_wait_api_rtos.cpp
# Compile [ 38.3%]: mbed_wait_api_no_rtos.c
# [Warning] mbed_wait_api_no_rtos.c@32,5: 'wait_ms' is deprecated: 'wait_ms' is deprecated in favor of explicit sleep functions. To sleep, 'wait_ms' should be replaced by 'ThisThread::sleep_for' (C++) or 'thread_sleep_for' (C). If you wish to wait (without sleeping), call 'wait_us'. 'wait_us' is safe to call from ISR context. [since mbed-os-5.14] [-Wdeprecated-declarations]
# Compile [ 38.7%]: mbed_printf_armlink_overrides.c
# Compile [ 39.0%]: mbed_rtc_time.cpp
# Compile [ 39.3%]: mbed_printf_wrapper.c
# Compile [ 39.7%]: mbed_retarget.cpp
# Compile [ 40.0%]: startup_stm32f746xx.S
# Compile [ 40.3%]: PeripheralPins.c
# Compile [ 40.7%]: mbed_printf_implementation.c
# Compile [ 41.0%]: system_clock.c
# Compile [ 41.3%]: analogin_device.c
# Compile [ 41.7%]: stm32f7xx_hal.c
# Compile [ 42.0%]: analogout_device.c
# Compile [ 42.3%]: stm32f7xx_hal_adc.c
# Compile [ 42.7%]: stm32f7xx_hal_adc_ex.c
# Compile [ 43.0%]: stm32f7xx_hal_can.c
# Compile [ 43.3%]: stm32f7xx_hal_cec.c
# Compile [ 43.7%]: stm32f7xx_hal_can_legacy.c
# Compile [ 44.0%]: stm32f7xx_hal_cortex.c
# Compile [ 44.3%]: stm32f7xx_hal_crc.c
# Compile [ 44.7%]: stm32f7xx_hal_crc_ex.c
# Compile [ 45.0%]: stm32f7xx_hal_cryp.c
# Compile [ 45.3%]: stm32f7xx_hal_cryp_ex.c
# Compile [ 45.7%]: stm32f7xx_hal_dac.c
# Compile [ 46.0%]: stm32f7xx_hal_dac_ex.c
# Compile [ 46.3%]: stm32f7xx_hal_dcmi.c
# Compile [ 46.7%]: stm32f7xx_hal_dcmi_ex.c
# Compile [ 47.0%]: stm32f7xx_hal_dfsdm.c
# Compile [ 47.3%]: stm32f7xx_hal_dma.c
# Compile [ 47.7%]: stm32f7xx_hal_dsi.c
# Compile [ 48.0%]: stm32f7xx_hal_dma2d.c
# Compile [ 48.3%]: stm32f7xx_hal_dma_ex.c
# Compile [ 48.7%]: stm32f7xx_hal_eth.c
# Compile [ 49.0%]: stm32f7xx_hal_flash.c
# Compile [ 49.3%]: stm32f7xx_hal_flash_ex.c
# Compile [ 49.7%]: stm32f7xx_hal_gpio.c
# Compile [ 50.0%]: stm32f7xx_hal_hash.c
# Compile [ 50.3%]: stm32f7xx_hal_hash_ex.c
# Compile [ 50.7%]: stm32f7xx_hal_hcd.c
# Compile [ 51.0%]: stm32f7xx_hal_i2c_ex.c
# Compile [ 51.3%]: stm32f7xx_hal_i2s.c
# Compile [ 51.7%]: stm32f7xx_hal_i2c.c
# Compile [ 52.0%]: stm32f7xx_hal_iwdg.c
# Compile [ 52.3%]: stm32f7xx_hal_irda.c
# Compile [ 52.7%]: stm32f7xx_hal_jpeg.c
# Compile [ 53.0%]: stm32f7xx_hal_lptim.c
# Compile [ 53.3%]: stm32f7xx_hal_ltdc_ex.c
# Compile [ 53.7%]: stm32f7xx_hal_mdios.c
# Compile [ 54.0%]: stm32f7xx_hal_ltdc.c
# Compile [ 54.3%]: stm32f7xx_hal_nor.c
# Compile [ 54.7%]: stm32f7xx_hal_nand.c
# Compile [ 55.0%]: stm32f7xx_hal_mmc.c
# Compile [ 55.3%]: stm32f7xx_hal_pcd.c
# Compile [ 55.7%]: stm32f7xx_hal_pcd_ex.c
# Compile [ 56.0%]: stm32f7xx_hal_pwr.c
# Compile [ 56.3%]: stm32f7xx_hal_pwr_ex.c
# Compile [ 56.7%]: stm32f7xx_hal_qspi.c
# Compile [ 57.0%]: stm32f7xx_hal_rng.c
# Compile [ 57.3%]: stm32f7xx_hal_rcc.c
# Compile [ 57.7%]: stm32f7xx_hal_rcc_ex.c
# Compile [ 58.0%]: stm32f7xx_hal_sai_ex.c
# Compile [ 58.3%]: stm32f7xx_hal_rtc.c
# Compile [ 58.7%]: stm32f7xx_hal_rtc_ex.c
# Compile [ 59.0%]: stm32f7xx_hal_sai.c
# Compile [ 59.3%]: stm32f7xx_hal_sdram.c
# Compile [ 59.7%]: stm32f7xx_hal_smartcard_ex.c
# Compile [ 60.0%]: stm32f7xx_hal_sd.c
# Compile [ 60.3%]: stm32f7xx_hal_smartcard.c
# Compile [ 60.7%]: stm32f7xx_hal_smbus.c
# Compile [ 61.0%]: stm32f7xx_hal_spdifrx.c
# Compile [ 61.3%]: stm32f7xx_hal_spi_ex.c
# Compile [ 61.7%]: stm32f7xx_hal_sram.c
# Compile [ 62.0%]: stm32f7xx_hal_spi.c
# Compile [ 62.3%]: stm32f7xx_hal_tim_ex.c
# Compile [ 62.7%]: stm32f7xx_hal_tim.c
# Compile [ 63.0%]: stm32f7xx_hal_wwdg.c
# Compile [ 63.3%]: stm32f7xx_hal_uart.c
# Compile [ 63.7%]: stm32f7xx_hal_usart.c
# Compile [ 64.0%]: stm32f7xx_ll_adc.c
# Compile [ 64.3%]: stm32f7xx_ll_crc.c
# [Warning] stm32f7xx_ll_crc.h@355,3: dereferencing type-punned pointer will break strict-aliasing rules [-Wstrict-aliasing]
# Compile [ 64.7%]: stm32f7xx_ll_dac.c
# Compile [ 65.0%]: stm32f7xx_ll_dma.c
# Compile [ 65.3%]: stm32f7xx_ll_exti.c
# Compile [ 65.7%]: stm32f7xx_ll_dma2d.c
# Compile [ 66.0%]: stm32f7xx_ll_fmc.c
# Compile [ 66.3%]: stm32f7xx_ll_gpio.c
# Compile [ 66.7%]: stm32f7xx_ll_i2c.c
# Compile [ 67.0%]: stm32f7xx_ll_lptim.c
# [Warning] stm32f7xx_ll_lptim.c@64,0: "IS_LPTIM_CLOCK_SOURCE" redefined
# [Warning] stm32f7xx_ll_lptim.c@67,0: "IS_LPTIM_CLOCK_PRESCALER" redefined
# [Warning] stm32f7xx_ll_lptim.c@79,0: "IS_LPTIM_OUTPUT_POLARITY" redefined
# Compile [ 67.3%]: stm32f7xx_ll_pwr.c
# Compile [ 67.7%]: stm32f7xx_ll_rcc.c
# Compile [ 68.0%]: stm32f7xx_ll_rng.c
# Compile [ 68.3%]: stm32f7xx_ll_rtc.c
# Compile [ 68.7%]: stm32f7xx_ll_sdmmc.c
# Compile [ 69.0%]: stm32f7xx_ll_spi.c
# Compile [ 69.3%]: stm32f7xx_ll_tim.c
# Compile [ 69.7%]: stm32f7xx_ll_usart.c
# Compile [ 70.0%]: stm32f7xx_ll_utils.c
# Compile [ 70.3%]: stm32f7xx_ll_usb.c
# Compile [ 70.7%]: system_stm32f7xx.c
# Compile [ 71.0%]: flash_api.c
# Compile [ 71.3%]: gpio_irq_device.c
# Compile [ 71.7%]: pwmout_device.c
# Compile [ 72.0%]: serial_device.c
# Compile [ 72.3%]: spi_api.c
# Compile [ 72.7%]: analogin_api.c
# Compile [ 73.0%]: analogout_api.c
# Compile [ 73.3%]: can_api.c
# Compile [ 73.7%]: gpio_api.c
# Compile [ 74.0%]: gpio_irq_api.c
# Compile [ 74.3%]: hal_tick_overrides.c
# Compile [ 74.7%]: USBPhy_STM32.cpp
# [Warning] USBPhy_STM32.cpp@434,23: variable 'ret' set but not used [-Wunused-but-set-variable]
# [Warning] USBPhy_STM32.cpp@461,14: variable 'len' set but not used [-Wunused-but-set-variable]
# [Warning] USBPhy_STM32.cpp@478,23: unused variable 'ret' [-Wunused-variable]
# [Warning] USBPhy_STM32.cpp@484,23: variable 'ret' set but not used [-Wunused-but-set-variable]
# [Warning] USBPhy_STM32.cpp@491,23: variable 'ret' set but not used [-Wunused-but-set-variable]
# [Warning] USBPhy_STM32.cpp@499,23: unused variable 'ret' [-Wunused-variable]
# [Warning] USBPhy_STM32.cpp@533,23: unused variable 'ret' [-Wunused-variable]
# [Warning] USBPhy_STM32.cpp@90,41: array subscript is above array bounds [-Warray-bounds]
# Compile [ 75.0%]: i2c_api.c
# Compile [ 75.3%]: mbed_crc_api.c
# Compile [ 75.7%]: lp_ticker.c
# Compile [ 76.0%]: mbed_overrides.c
# Compile [ 76.3%]: pinmap.c
# Compile [ 76.7%]: port_api.c
# Compile [ 77.0%]: pwmout_api.c
# Compile [ 77.3%]: qspi_api.c
# [Warning] qspi_api.c@178,150: format '%x' expects argument of type 'unsigned int', but argument 7 has type 'uint32_t {aka const long unsigned int}' [-Wformat=]
# [Warning] qspi_api.c@269,76: format '%x' expects argument of type 'unsigned int', but argument 3 has type 'uint32_t {aka long unsigned int}' [-Wformat=]
# [Warning] qspi_api.c@269,91: format '%x' expects argument of type 'unsigned int', but argument 4 has type 'uint32_t {aka long unsigned int}' [-Wformat=]
# [Warning] qspi_api.c@269,106: format '%x' expects argument of type 'unsigned int', but argument 5 has type 'uint32_t {aka long unsigned int}' [-Wformat=]
# [Warning] qspi_api.c@269,121: format '%x' expects argument of type 'unsigned int', but argument 6 has type 'uint32_t {aka long unsigned int}' [-Wformat=]
# [Warning] qspi_api.c@269,132: format '%x' expects argument of type 'unsigned int', but argument 7 has type 'uint32_t {aka long unsigned int}' [-Wformat=]
# [Warning] qspi_api.c@269,144: format '%x' expects argument of type 'unsigned int', but argument 8 has type 'uint32_t {aka long unsigned int}' [-Wformat=]
# Compile [ 77.7%]: reset_reason.c
# Compile [ 78.0%]: rtc_api.c
# Compile [ 78.3%]: serial_api.c
# Compile [ 78.7%]: sleep.c
# Compile [ 79.0%]: stm_spi_api.c
# Compile [ 79.3%]: trng_api.c
# Compile [ 79.7%]: us_ticker.c
# Compile [ 80.0%]: common.c
# Compile [ 80.3%]: watchdog_api.c
# Compile [ 80.7%]: error_reporter.cc
# Compile [ 81.0%]: tensor_utils.cc
# Compile [ 81.3%]: quantization_util.cc
# Compile [ 81.7%]: classify_heartbeats_cnn.cc
# Compile [ 82.0%]: kernel_util.cc
# Compile [ 82.3%]: main.cc
# Compile [ 82.7%]: classify_heartbeats_cnn_quantized.cc
# Compile [ 83.0%]: op_resolver.cc
# [Warning] op_resolver.cc@33,20: comparison is always false due to limited range of data type [-Wtype-limits]
# Compile [ 83.3%]: activations.cc
# Compile [ 83.7%]: add.cc
# Compile [ 84.0%]: flatbuffer_conversions.cc
# Compile [ 84.3%]: main_functions.cc
# [Warning] main_functions.cc@219,15: 'void wait_ms(int)' is deprecated: 'wait_ms' is deprecated in favor of explicit sleep functions. To sleep, 'wait_ms' should be replaced by 'ThisThread::sleep_for' (C++) or 'thread_sleep_for' (C). If you wish to wait (without sleeping), call 'wait_us'. 'wait_us' is safe to call from ISR context. [since mbed-os-5.14] [-Wdeprecated-declarations]
# [Warning] main_functions.cc@251,83: embedded '\0' in format [-Wformat-contains-nul]
# [Warning] main_functions.cc@256,19: 'void wait_ms(int)' is deprecated: 'wait_ms' is deprecated in favor of explicit sleep functions. To sleep, 'wait_ms' should be replaced by 'ThisThread::sleep_for' (C++) or 'thread_sleep_for' (C). If you wish to wait (without sleeping), call 'wait_us'. 'wait_us' is safe to call from ISR context. [since mbed-os-5.14] [-Wdeprecated-declarations]
# [Warning] main_functions.cc@259,20: 'void wait_ms(int)' is deprecated: 'wait_ms' is deprecated in favor of explicit sleep functions. To sleep, 'wait_ms' should be replaced by 'ThisThread::sleep_for' (C++) or 'thread_sleep_for' (C). If you wish to wait (without sleeping), call 'wait_us'. 'wait_us' is safe to call from ISR context. [since mbed-os-5.14] [-Wdeprecated-declarations]
# Compile [ 84.7%]: arg_min_max.cc
# Compile [ 85.0%]: ceil.cc
# Compile [ 85.3%]: all_ops_resolver.cc
# Compile [ 85.7%]: circular_buffer.cc
# Compile [ 86.0%]: conv.cc
# Compile [ 86.3%]: concatenation.cc
# Compile [ 86.7%]: depthwise_conv.cc
# Compile [ 87.0%]: comparisons.cc
# Compile [ 87.3%]: elementwise.cc
# Compile [ 87.7%]: dequantize.cc
# Compile [ 88.0%]: floor.cc
# Compile [ 88.3%]: fully_connected.cc
# Compile [ 88.7%]: logical.cc
# Compile [ 89.0%]: l2norm.cc
# Compile [ 89.3%]: logistic.cc
# Compile [ 89.7%]: maximum_minimum.cc
# Compile [ 90.0%]: neg.cc
# Compile [ 90.3%]: mul.cc
# Compile [ 90.7%]: pack.cc
# Compile [ 91.0%]: pad.cc
# Compile [ 91.3%]: prelu.cc
# Compile [ 91.7%]: pooling.cc
# Compile [ 92.0%]: quantize.cc
# Compile [ 92.3%]: reduce.cc
# Compile [ 92.7%]: reshape.cc
# Compile [ 93.0%]: resize_nearest_neighbor.cc
# Compile [ 93.3%]: round.cc
# Compile [ 93.7%]: split.cc
# Compile [ 94.0%]: softmax.cc
# Compile [ 94.3%]: strided_slice.cc
# Compile [ 94.7%]: sub.cc
# Compile [ 95.0%]: debug_log.cc
# Compile [ 95.3%]: unpack.cc
# Compile [ 95.7%]: linear_memory_planner.cc
# Compile [ 96.0%]: svdf.cc
# Compile [ 96.3%]: greedy_memory_planner.cc
# Compile [ 96.7%]: micro_error_reporter.cc
# Compile [ 97.0%]: memory_helpers.cc
# Compile [ 97.3%]: micro_string.cc
# [Warning] micro_string.cc@128,53: dereferencing type-punned pointer will break strict-aliasing rules [-Wstrict-aliasing]
# Compile [ 97.7%]: micro_time.cc
# Compile [ 98.0%]: micro_utils.cc
# Compile [ 98.3%]: micro_allocator.cc
# Compile [ 98.7%]: micro_interpreter.cc
# [Warning] micro_interpreter.cc@264,14: comparison of unsigned expression < 0 is always false [-Wtype-limits]
# [Warning] micro_interpreter.cc@275,14: comparison of unsigned expression < 0 is always false [-Wtype-limits]
# [Warning] micro_interpreter.cc@286,14: comparison of unsigned expression < 0 is always false [-Wtype-limits]
# Compile [ 99.0%]: micro_optional_debug_tools.cc
# Compile [ 99.3%]: simple_memory_allocator.cc
# Compile [ 99.7%]: test_utils.cc
# [Warning] test_utils.cc@84,20: comparison between signed and unsigned integer expressions [-Wsign-compare]
# Compile [100.0%]: test_helpers.cc
# Link: mbed
# Elf2Bin: mbed
# | Module                              |         .text |       .data |            .bss |
# |-------------------------------------|---------------|-------------|-----------------|
# | BSP_DISCO_F746NG\Drivers            |   2420(+2420) |       1(+1) |       584(+584) |
# | BSP_DISCO_F746NG\Utilities          |         0(+0) |       8(+8) |           0(+0) |
# | LCD_DISCO_F746NG\LCD_DISCO_F746NG.o |     168(+168) |       0(+0) |           0(+0) |
# | [fill]                              |     120(+120) |     14(+14) |         26(+26) |
# | [lib]\c.a                           | 30256(+30256) | 2472(+2472) |         89(+89) |
# | [lib]\gcc.a                         |   3452(+3452) |       0(+0) |           0(+0) |
# | [lib]\m.a                           |   1220(+1220) |       1(+1) |           0(+0) |
# | [lib]\misc                          |     180(+180) |       4(+4) |         28(+28) |
# | [lib]\nosys.a                       |       32(+32) |       0(+0) |           0(+0) |
# | [lib]\stdc++.a                      |       40(+40) |       0(+0) |         16(+16) |
# | mbed-os\drivers                     |     904(+904) |       0(+0) |           0(+0) |
# | mbed-os\hal                         |   1374(+1374) |       8(+8) |       130(+130) |
# | mbed-os\platform                    |   3724(+3724) |   260(+260) |       240(+240) |
# | mbed-os\targets                     | 12506(+12506) |       4(+4) |     1164(+1164) |
# | tensorflow\lite                     | 30520(+30520) |   260(+260) | 108043(+108043) |
# | Subtotals                           | 86916(+86916) | 3032(+3032) | 110320(+110320) |
# Total Static RAM memory (data + bss): 113352(+113352) bytes
# Total Flash memory (text + data): 89948(+89948) bytes
#
# Image: .\BUILD\DISCO_F746NG\GCC_ARM\mbed.bin
# [mbed] Working path "C:\Projects\McuML\projects\tflite_micro_classify_heartbeats\mbed" (program)

# %%
DIS_F746NG = 'D:\\'
cmd = 'copy .\\BUILD\\DISCO_F746NG\\GCC_ARM\\mbed.bin ' + DIS_F746NG
print(os.popen(cmd).read())
# Out:
# 複製了         1 個檔案。
